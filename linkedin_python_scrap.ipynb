# %%
import pandas as pd

# %%
data= pd.read_csv("/Users/otbot/Downloads/hubspot-crm-exports-tous-les-contacts-2024-04-03.xlsx - Tous les contacts.csv")

# %%
data.head()
# Out:
#    ID de fiche d'informations       Prénom             Nom  \
# 0                  8888024611      Stephan       Ledouarec
# 1                  8901587569        Sonia         Musnier
# 2                  8903160167  Anne-Cécile  FICHET-JOUBERT
# 3                  8901587047         Lena           Jaros
# 4                  8901592335       Thomas         Raphael
#
#                            E-mail Nom de l'entreprise École  \
# 0                      sl@i-we.fr                 NaN   NaN
# 1          sonia.musnier@etik.com                 NaN   NaN
# 2      reevolve.conseil@gmail.com                 NaN   NaN
# 3  lena.jaros.formation@gmail.com                 NaN   NaN
# 4           raphael4431@gmail.com                 NaN   NaN
#
#   Numéro de téléphone         Origine du contact  \
# 0                 NaN  Isabelle Werlen-Eschalier
# 1        +33610822187                      Le 47
# 2                 NaN                        NaN
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# Chemin vers le driver de votre navigateur, par exemple pour Chrome
driver_path = 'chromedriver.ex'

# Instanciation du driver
driver = webdriver.Chrome(driver_path)

# Ouvrir LinkedIn
driver.get('https://www.linkedin.com')



""""
# Attendre que la page soit complètement chargée
time.sleep(2)

# Remplir le formulaire de connexion
email_input = driver.find_element_by_id('session_key')
password_input = driver.find_element_by_id('session_password')

email_input.send_keys('votre_email@exemple.com')
password_input.send_keys('votre_mot_de_passe')
password_input.send_keys(Keys.RETURN)

# Attendre que la page soit complètement chargée après la connexion
time.sleep(5)

# Naviguer vers le profil souhaité
driver.get('url_du_profil_linkedin')

# Récupérer les informations du profil
nom = driver.find_element_by_class_name('pv-top-card-section__name').text
titre = driver.find_element_by_class_name('pv-top-card-section__headline').text
localisation = driver.find_element_by_class_name('pv-top-card-section__location').text
# et ainsi de suite pour récupérer les autres informations

# Fermer le navigateur
driver.quit()
"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/driver_finder.py in get_path(service, options)
#      37         try:
# ---> 38             path = SeleniumManager().driver_location(options) if path is None else path
#      39         except Exception as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/selenium_manager.py in driver_location(self, options)
#      86
# ---> 87         browser = options.capabilities["browserName"]
#      88
#
# AttributeError: 'str' object has no attribute 'capabilities'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /var/folders/m8/rcj_ns0s6fxbs3lw42qyb71r0000gn/T/ipykernel_45486/4134902748.py in <module>
#       7
# ...

# %%
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 68.1 MB/s eta 0:00:0000:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 46.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.3.0
#     Uninstalling typing_extensions-4.3.0:
#       Successfully uninstalled typing_extensions-4.3.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.4.0
#     Uninstalling attrs-21.4.0:
#       Successfully uninstalled attrs-21.4.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Traceback (most recent call last):
#
#   File "/Users/otbot/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/var/folders/m8/rcj_ns0s6fxbs3lw42qyb71r0000gn/T/ipykernel_40951/641971552.py", line 1, in <module>
#     from linkedin import linkedin
#
#   File "/Users/otbot/opt/anaconda3/lib/python3.9/site-packages/linkedin/linkedin.py", line 294
#     except (requests.ConnectionError, requests.HTTPError), error:
#                                                          ^
# SyntaxError: invalid syntax
